# %% [markdown]
# ### use of for loop

# %%
users = {
    "uxman00021@gmail.com": "6543210",
    "admin@gmail.com": "12345"
}

add_user = int(input("How many new users do you want to add? "))

for i in range(add_user):
    email = input(f"Enter new user email #{i+1}: ")
    password = input(f"Enter password for {email}: ")
    users[email] = password

print("\n Updated user database:")
print(users)
# Out:
# How many new users do you want to add?  5
# Enter new user email #1:  fahadmustafa@gmail.com
# Enter password for fahadmustafa@gmail.com:  123456
# Enter new user email #2:  abid@gmail.com
# Enter password for abid@gmail.com:  32103210
# Enter new user email #3:  arslan@gmail.com
# Enter password for arslan@gmail.com:  1234567
# Enter new user email #4:  kashif@gmail.com
# Enter password for kashif@gmail.com:  kasi123
# Enter new user email #5:  salman@gmail.com
# Enter password for salman@gmail.com:  987654
#  Updated user database:
# {'uxman00021@gmail.com': '6543210', 'admin@gmail.com': '12345', 'fahadmustafa@gmail.com': '123456', 'abid@gmail.com': '32103210', 'arslan@gmail.com': '1234567', 'kashif@gmail.com': 'kasi123', 'salman@gmail.com': '987654'}

# %% [markdown]
# ### Login System using for loop

# %%
for attempt in range(3):
    Email = input("Enter your email: ")

    if '@' in Email:
        Password = input("Enter your password: ")

        if Email in users and users[Email] == Password:
            print("Login Successful! Welcome,", Email)
            break
        else:
            print("Incorrect email or password. Try again.")
    else:
        print("Invalid email format.")
else:
    print("Too many failed attempts. Try again later.")
# Out:
# Enter your email:  salman@gmail.com
# Enter your password:  98765
# Incorrect email or password. Try again.
# Enter your email:  salma@gmail.com
# Enter your password:  987654
# Incorrect email or password. Try again.
# Enter your email:  salmangmail.com
# Invalid email format.
# Too many failed attempts. Try again later.

# %% [markdown]
# ### Login System using while loop

# %%
print("Login System (WHILE LOOP)")
login_success = False

while not login_success:
    Email = input("Enter your email: ")

    if '@' in Email:
        Password = input("Enter your password: ")

        if Email in users and users[Email] == Password:
            print("Login Successful! Welcome,", Email)
            login_success = True
        else:
            print("Incorrect information. Please try again.\n")
    else:
        print("Wrong email format")
# Out:
# Login System (WHILE LOOP)
# Enter your email:  kashifgmail.com
# Wrong email format.
# Enter your email:  adil@gmail.com
# Enter your password:  321456
# Incorrect information. Please try again.
# Enter your email:  kashif@gmail.com
# Enter your password:  kasi123
# Login Successful! Welcome, kashif@gmail.com

# %% [markdown]
# ### Optional Task

# %%
#### asterisk table with 4 columns and 6 rows using loops.

# %%
rows = 6
columns = 4
for i in range(rows): #
    for j in range(columns):
        print("*", end=" ")
    print()
# Out:
# * * * *
# * * * *
# * * * *
# * * * *
# * * * *
# * * * *

# %%
i = 0
while i < 6:
    j = 0
    while j < 4:
        print("*", end=" ")
        j += 1
    print()
    i += 1
# Out:
# * * * *
# * * * *
# * * * *
# * * * *
# * * * *
# * * * *
